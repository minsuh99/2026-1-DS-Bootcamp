# %% [markdown]
# # 1일차 과제

# %% [markdown]
# ## 1. 아래 명령에 해당하는 코드를 작성하세요.
#
# - "Hello World!"를 출력하세요.
# - 본인의 이름을 출력하세요.
# - 본인이 사용하는 Python Interpreter 버전을 출력하세요. (힌트: 강의자료 참고)

# %%
import sys
# 본인의 코드를 작성하세요.
