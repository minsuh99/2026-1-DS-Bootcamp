# %% [markdown]
# # 2일차 과제

# %% [markdown]
# ## 1. 아래 지시사항을 참고하여 계산기 프로그램을 만드세요.
#
# <입력>
#
# 다음과 같은 순서로 입력 진행 (실제 계산기처럼)
# - 첫 번째 정수 입력
# - 연산자 입력 (+, -, *, //, %, **)
# - 두 번째 정수 입력
#
# <출력>
# - 두 정수와 연산자에 맞는 연산 결과
#
# <조건>
# - 연산자가 (+, -, *, //, %, **) 중에 없는 연산자를 입력하면 다시 입력받게 작성하세요.

# %%
# 본인의 코드를 작성하세요.

# %% [markdown]
# ## 2. 아래 지시사항을 참고하여 퀴즈 프로그램을 만드세요.
#
# <입력>
#
# N개의 퀴즈에 대한 답 차례로 입력
# - 첫 번째 퀴즈에 대한 답 입력
# - 두 번째 퀴즈에 대한 답 입력
# - ...
# - N 번째 퀴즈에 대한 답 입력
#
# <출력>
# - 퀴즈 정답률
#
# <조건>
# - N >= 3
# - 퀴즈는 모든 주제에 관해 본인이 직접 문제를 만드시면 됩니다.
# - 입력 프롬프트에 문제가 표시되어야 합니다.

# %%
# 본인의 코드를 작성하세요.
