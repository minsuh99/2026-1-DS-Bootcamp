# %% [markdown]
# # 3일차 과제

# %% [markdown]
# ## 1. 아래 지시사항을 참고하여 하루 활동 기록 프로그램을 만드세요.
#
# <입력>
# - 하루 동안 수행한 활동을 '/' 기호로 구분하여 차례대로 입력 (-1 입력하면 입력 종료)
#   - 활동 이름
#   - 소요 시간 (시간 단위, 분 단위 설정은 자유)
#   - 만족도 (1~5)
#
# - 입력 예시:
#     - `부트캠프 수강/3시간/5`
#     - `운동/1시간/4`
#     - `독서/30분/3`
#     - `-1`
#
# <출력>
# - 입력한 모든 활동을 **정리된 형태로 출력**
# - 출력 형식은 자유
#
# <출력 예시>
# ```
# [하루 활동 요약]
# - 총 활동 수: 3
# - 가장 오래 한 활동: 부트캠프 수강
# - 평균 만족도: 4.0
# ```
#
# <조건>
# - 모든 활동 정보는 **리스트 또는 딕셔너리**를 사용하여 저장하세요.
# - 활동은 **최소 3개 이상** 입력해야 함

# %%
# 본인의 코드를 작성하세요.

# %% [markdown]
# ## 2. 아래 지시사항을 참고하여 비밀번호 검증 프로그램을 만드세요.
#
# <입력>
# - 사용하고자 하는 비밀번호 (문자열)
#
# <출력>
# - 비밀번호를 사용할 수 있는지 여부 출력
# - 사용할 수 있다면
#   → `사용 가능합니다.`
# - 사용할 수 없다면
#   → `사용할 수 없습니다.`
#
# <조건>
# - 비밀번호 검증을 수행하는 **함수**를 작성하고 이를 활용하세요
# - 함수 내부에서 `print` 사용 X
# - 비밀번호 사용 가능 조건
#     - 길이 8 이상
#     - 숫자 최소 1개 이상 포함
#       - <힌트> `isdigit()`: 문자열이 숫자로 구성되어 있는지 확인하는 함수
#     - 알파벳 최소 1개 이상 포함
#       - <힌트> `isalpha()`: 문자열이 알파벳으로 구성되어 있는지 확인하는 함수

# %%
# 본인의 코드를 작성하세요.
